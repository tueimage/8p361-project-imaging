# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
import sys
sys.path.append("../code")
from mlp2 import neural_network_classification 

neural_network_classification(datafile=mnist.load_data(), batch_size=32, epochs=10, hidden_layers=1, neurons=64)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 1.1543 - accuracy: 0.6818 - val_loss: 0.4295 - val_accuracy: 0.8802
# Epoch 2/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3819 - accuracy: 0.8945 - val_loss: 0.3517 - val_accuracy: 0.8985
# Epoch 3/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3193 - accuracy: 0.9107 - val_loss: 0.3135 - val_accuracy: 0.9093
# Epoch 4/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2880 - accuracy: 0.9190 - val_loss: 0.2890 - val_accuracy: 0.9152
# Epoch 5/10
# 1688/1688 [==============================] - 6s 4ms/step - loss: 0.2671 - accuracy: 0.9257 - val_loss: 0.2710 - val_accuracy: 0.9207
# Epoch 6/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2470 - accuracy: 0.9319 - val_loss: 0.2525 - val_accuracy: 0.9282
# Epoch 7/10
# ...

# %%
neural_network_classification(datafile=mnist.load_data(), batch_size=32, epochs=20, hidden_layers=1, neurons=64)
# Out:
# Epoch 1/20
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.0743 - accuracy: 0.7230 - val_loss: 0.4189 - val_accuracy: 0.8845
# Epoch 2/20
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3674 - accuracy: 0.8987 - val_loss: 0.3518 - val_accuracy: 0.8997
# Epoch 3/20
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.3146 - accuracy: 0.9110 - val_loss: 0.3177 - val_accuracy: 0.9097
# Epoch 4/20
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2825 - accuracy: 0.9198 - val_loss: 0.2927 - val_accuracy: 0.9173
# Epoch 5/20
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2628 - accuracy: 0.9266 - val_loss: 0.2729 - val_accuracy: 0.9250
# Epoch 6/20
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.2444 - accuracy: 0.9306 - val_loss: 0.2599 - val_accuracy: 0.9270
# Epoch 7/20
# ...

# %%
neural_network_classification(datafile=mnist.load_data(), batch_size=64, epochs=10, hidden_layers=1, neurons=64)
# Out:
# Epoch 1/10
# 844/844 [==============================] - 5s 5ms/step - loss: 1.3991 - accuracy: 0.6284 - val_loss: 0.5386 - val_accuracy: 0.8652
# Epoch 2/10
# 844/844 [==============================] - 3s 4ms/step - loss: 0.4787 - accuracy: 0.8750 - val_loss: 0.4164 - val_accuracy: 0.8853
# Epoch 3/10
# 844/844 [==============================] - 3s 4ms/step - loss: 0.3817 - accuracy: 0.8954 - val_loss: 0.3688 - val_accuracy: 0.9000
# Epoch 4/10
# 844/844 [==============================] - 3s 4ms/step - loss: 0.3367 - accuracy: 0.9078 - val_loss: 0.3409 - val_accuracy: 0.9052
# Epoch 5/10
# 844/844 [==============================] - 3s 4ms/step - loss: 0.3145 - accuracy: 0.9111 - val_loss: 0.3217 - val_accuracy: 0.9107
# Epoch 6/10
# 844/844 [==============================] - 3s 4ms/step - loss: 0.2989 - accuracy: 0.9149 - val_loss: 0.3050 - val_accuracy: 0.9178
# Epoch 7/10
# ...

# %%
neural_network_classification(datafile=mnist.load_data(), batch_size=64, epochs=20, hidden_layers=1, neurons=64)
# Out:
# Epoch 1/20
# 844/844 [==============================] - 5s 5ms/step - loss: 1.3724 - accuracy: 0.6262 - val_loss: 0.5259 - val_accuracy: 0.8635
# Epoch 2/20
# 844/844 [==============================] - 4s 4ms/step - loss: 0.4671 - accuracy: 0.8772 - val_loss: 0.4161 - val_accuracy: 0.8865
# Epoch 3/20
# 844/844 [==============================] - 4s 4ms/step - loss: 0.3762 - accuracy: 0.8981 - val_loss: 0.3739 - val_accuracy: 0.8938
# Epoch 4/20
# 844/844 [==============================] - 4s 5ms/step - loss: 0.3376 - accuracy: 0.9050 - val_loss: 0.3454 - val_accuracy: 0.9012
# Epoch 5/20
# 844/844 [==============================] - 3s 4ms/step - loss: 0.3184 - accuracy: 0.9101 - val_loss: 0.3264 - val_accuracy: 0.9082
# Epoch 6/20
# 844/844 [==============================] - 4s 4ms/step - loss: 0.3052 - accuracy: 0.9143 - val_loss: 0.3107 - val_accuracy: 0.9093
# Epoch 7/20
# ...
